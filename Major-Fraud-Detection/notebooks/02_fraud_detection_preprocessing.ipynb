# %% [markdown]
# # Fraud Detection — Data Preprocessing
#
# This notebook prepares the credit card transaction dataset for machine learning.
#
# ## Objectives
#
# - Load and inspect the dataset
# - Separate features and target
# - Perform train-test split
# - Handle class imbalance
# - Scale features where required
# - Prepare the final datasets for model training

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler

# 1. Load Data
df = pd.read_csv('../data/raw/creditcard.csv')

# 2. Separate Features & Target
X = df.drop(columns=['Class'])
y = df['Class']

# 3. Stratified Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)

# 4. Scale Amount and Time using RobustScaler
scaler_amount = RobustScaler()
scaler_time = RobustScaler()

X_train['scaled_amount'] = scaler_amount.fit_transform(X_train[['Amount']])
X_test['scaled_amount'] = scaler_amount.transform(X_test[['Amount']])

X_train['scaled_time'] = scaler_time.fit_transform(X_train[['Time']])
X_test['scaled_time'] = scaler_time.transform(X_test[['Time']])

X_train = X_train.drop(columns=['Amount', 'Time'])
X_test = X_test.drop(columns=['Amount', 'Time'])

# 5. Save Processed Datasets
os.makedirs('../data/processed', exist_ok=True)
X_train.to_csv('../data/processed/X_train.csv', index=False)
y_train.to_csv('../data/processed/y_train.csv', index=False)
X_test.to_csv('../data/processed/X_test.csv', index=False)
y_test.to_csv('../data/processed/y_test.csv', index=False)

print("Preprocessing complete without SMOTE!")
# Out:
# Preprocessing complete without SMOTE!
